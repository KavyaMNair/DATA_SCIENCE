# %%
import matplotlib.pyplot as plt

languages = 'Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'
popuratity = [22.2, 17.6, 8.8, 8, 77, 6.7]
clr = ["r", "m", "g", "c", "y", "b"]

expld = (0.1,0,0,0,0,0)  

plt.pie(popuratity, explode=expld, labels=languages, colors=clr,autopct='%1.1f%%')
plt.show()
